# %% [markdown]
# <a href="https://colab.research.google.com/github/hollyakt/hollyakt/blob/main/ImgOverlay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

#matplotlib inline
# reading image
img = cv2.imread(r"/Brain1.jpg")
img = cv2.imread(r"/Brain2.jpg")

# Edges

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.medianBlur(gray, 5)
edges = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C,
                                         cv2.THRESH_BINARY, 9, 9)

# Cartoonization
color = cv2.bilateralFilter(img, 9, 250, 250)
cartoon = cv2.bitwise_and(color, color, mask=edges)

# cv2.imshow("Image", img)
# cv2.imshow("edges", edges)
# cv2.imshow("Cartoon", cartoon)
plt.imshow(img)
plt.imshow(edges)
